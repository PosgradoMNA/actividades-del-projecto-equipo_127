# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo_127/blob/main/Proyecto_Final_Avance_2_Equipo127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Avance 2

# %%
#La metodología que se utilizará para este proyecto será CRISP
metodologia = "CRISP"

# %%
# Paso 1: Entendimiento de negocio
#Desde mi punto de vista este es el más importante debido a que sin una alieación con negocio o un KPI a impactar
#seguramente los resultados no van a tener el impacto necesario
#También durante este paso podemos generar preguntas de negocio que sean interesantes a responder y complementen el caso en cuestión o den pie a nuevas iniciativas

# %%
# Paso 2: Entendimiento de datos
# Este paso es muy relevanta debido a que aqui se puede evaluar la viabilidad técnica del caso de uso a resolver. Puede que queramos desarrollar un modelo de abandono o de
# scoring crediticio sin embargo la información que se tiene no es relevante o no tiene la calidad suficiente. De igual manera en esta fase podemos descubrir necesidades que no teníamos en
# mente una vez revisado el "estado" de nuestros datos

# %%
#Paso 3: Preparación de datos
# Este paso es el que nos ayuda a asegurar que los resultados de nuestros modelos sean de calidad generando diferentes procesos de limpieza, estandarización y enriquecimiento de la
# información para poder cumplir con los supuestos de nuestras diferentes estrategias de modelado y las condiciones para un buen "performance" de los mismos

# %%
# Paso 4: Modelado
# Este paso es el corazón de cualquier iniciativa y metodología de ciencia de datos. En este paso buscamos generar un modelo que mejor se adapte y explique el fenómeno en cuestión.
# Podemos hablar de modelos de abandono, riesgo crediticio, fraude, siguiente mejor oferta, etc. Un punto muy importante en este paso es utilizar diferentes estrategias y familias de modelos para 
# poder encontrar el modelo "campeón"

# %%
# Paso 5: Evaluación
# En este paso determinamos con base en los diferentes estadísticos de rendimiento de los modelos cuál es el que más nos conviene usar. No siempre el más asertivo es la mejor opción.
# Un buen ejemplo fue la copetencia para un nuevo sistema de recomendación para Netflix en 2017. Los dos primeros lugares de la competencia fueron descartados por los altos tiempos de procesamiento 
# que requería para emitir las recomendaciones, ganaron los premios pero fue el tercer luga el que se implementó en la plataforma por su velocidad.

# %%
# Paso 6: Despliegue
# Dentro de mi experiencia este es el que tiene mayores áreas de oportunidad y el mayor cuello de botella para las organizaciones. Los científicos de datos se enfocan en generar lso modelos
# más asertivos pero no siempre tienen en cuenta la operacionalización de los mismos en mente y cuando llega esta tarea al encargado, incluso hay veces que se tiene que recodificar para poder embeber 
# el modelo dentro de los procesos de negocio de la organización

# %%
# Se añadieron algunas iteraciones extra para la metodología CRISP alineando a prácticas ágiles y lo que ayudará a tener una estrategia de modelado resiliente a través del tiempo
# a partir de una constante evaluación

# %% [markdown]
# ![My First Board.jpg](data:image/jpeg;base64,...)
